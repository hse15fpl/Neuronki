# %% [markdown]
# # Лабораторная работа 1: Реккурентные нейронные сети и слой Embedding

# %% [markdown]
# **Выполнили:** Алёшина Арина, Базылева Алена (15ФПЛ)

# %% [markdown]
# ## Задача 2: Генерация текстов

# %%
from keras.layers.recurrent import LSTM, GRU
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
import numpy as np
from nltk.tokenize import word_tokenize
import math

# %% [markdown]
# В качестве текстов для обучения генератора были выбраны книги С. Лукьяненко "Ночной дозор" и "Дневной дозор"

# %%
INPUT_FILE = "1_nochnoy_dozor.txt"
TEST_FILE = "2_dnevnoy_dozor.txt"

# extract the input as a stream of characters
print("Extracting text from input...")
file1 = open(INPUT_FILE, 'r', encoding='utf-8')
lines1 = []
for line in file1:
    line = line.strip().lower()
    if len(line) == 0:
        continue
    lines1.append(line)
file1.close()
text_1 = " ".join(lines1)
text_1 = re.sub('\ufeff', '', text_1)

file2 = open(TEST_FILE, 'r', encoding='utf-8')
lines2 = []
for line in file2:
    line = line.strip().lower()
    if len(line) == 0:
        continue
    lines2.append(line)
file2.close()
text_2 = " ".join(lines2)
text_2 = re.sub('\ufeff', '', text_2)
# Out:
# Extracting text from input...

# %%
train_tokens = [tok for tok in word_tokenize(text_1) if tok.isalpha()][:10000]
test_tokens_all = [tok for tok in word_tokenize(text_2) if tok.isalpha()][:10000]
test_tokens = [tok for tok in test_tokens_all if tok in train_tokens]  #выкидываем новые слова из тестового корпуса

# %% [markdown]
# Уменьшение кол-ва входных данных сделано с целью предотвращения ошибки MemoryError на этапе векторизации данных. Изначально планировалось использовать метод генераторов и функции fit_generator (и аналогичные), но при их использовании jupyter сильно зависает и в конце-концов отключается. Поэтому был применен несколько "варварский" метод сокращения объема данных.

# %%
chars = list(set(train_tokens))
nb_chars = len(chars)
char2index = dict((c,i) for i, c in enumerate(chars))
index2char = dict((i,c) for i, c in enumerate(chars))

# %% [markdown]
# Для предсказания был выбран размер последовательности 4, т.к. согласно некоторым исследованиям (потеряли ссылку, просим прощения), n-граммы из 5 слов хорошо предсказываются моделями

# %%
SEQLEN = 4
STEP = 1

# %%
train_chars = []
train_labels = []
test_chars = []
test_labels = []
for i in range(0, len(train_tokens) - SEQLEN, STEP):
    train_chars.append(train_tokens[i:i + SEQLEN])
    train_labels.append(train_tokens[i + SEQLEN])
for j in range(0, len(test_tokens) - SEQLEN, STEP):
    test_chars.append(test_tokens[j:j + SEQLEN])
    test_labels.append(test_tokens[j + SEQLEN])

# %%
X = np.zeros((len(train_chars), SEQLEN))
y = np.zeros((len(train_chars), nb_chars))
for i, input_char in enumerate(train_chars):
    for j, ch in enumerate(input_char):
        X[i, j] = char2index[ch]
    y[i, char2index[train_labels[i]]] = 1
Xtrain, Xval, Ytrain, Yval = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Функции для подсчета перплексии и качества работы модели

# %%
def perplexity(probabilities):
    sumlog = 0
    for probability in probabilities:
        log_prob = math.log2(probability)
        sumlog += log_prob
    l = sumlog/len(probabilities)
    perp = math.pow(2, -l)
    return perp

# %%
def eval_model(model):
    example = []
    for i in range(len(test_chars)):
        probabilities = []
        test_input = test_chars[i]
        test_l = test_labels[i]
        test_s = np.zeros((1, SEQLEN))
        for w, word in enumerate(test_chars):
            test_s[0, w] = char2index[word]
        pred = model.predict(test_s, verbose=0)[0]
        probability = pred[char2index[test_l]]
        probabilities.append(probability)
    perp = perplexity(probabilities)
    return perp

# %% [markdown]
# ### LSTM

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 128
NUM_ITERATIONS = 25
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100

model = Sequential()
model.add(Embedding(nb_chars, 100, input_length=SEQLEN))
model.add(LSTM(HIDDEN_SIZE, return_sequences=False,
                    input_shape=(SEQLEN, nb_chars),
                    unroll=True))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))

model.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=['acc'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 4, 100)            407000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               117248
# _________________________________________________________________
# dense_4 (Dense)              (None, 4070)              525030
# _________________________________________________________________
# activation_4 (Activation)    (None, 4070)              0
# =================================================================
# Total params: 1,049,278
# Trainable params: 1,049,278
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Эксперименты с размерами слоя Embedding показали, что при увеличении этого показателя (200 и далее) качество генерируемого текста несколько хуже, в то время как сильное его уменьшение порождает последовательность 5-7 однотипных предлогов или местоимений

# %%
for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model.fit(Xtrain, Ytrain, validation_data=[Xval, Yval], batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    
    test_idx = np.random.randint(len(train_chars))
    test_chars = train_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(' '.join(test_chars))
    for i in range(NUM_PREDS_PER_EPOCH):
        test_seq = np.zeros((1, SEQLEN))
        for i, ch in enumerate(test_chars):
            test_seq[0, i] = char2index[ch]
        pred = model.predict(test_seq, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print(ypred, end=" ")
        test_chars = test_chars[1:] + [ypred]
    print()
# Out:
# ==================================================
# Iteration #: 0
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 7.7833 - acc: 0.0259 - val_loss: 7.6046 - val_acc: 0.0290
# Generating from seed: ['убил', 'бы', 'меня', 'инициировал']
# убил бы меня инициировал
# не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 1
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 7s 879us/step - loss: 7.2448 - acc: 0.0279 - val_loss: 7.8667 - val_acc: 0.0225
# Generating from seed: ['ваше', 'благородие', 'не', 'рад']
# ваше благородие не рад
# в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в
# ==================================================
# Iteration #: 2
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 7s 921us/step - loss: 7.1514 - acc: 0.0281 - val_loss: 8.1794 - val_acc: 0.0285
# Generating from seed: ['мгновенно', 'стали', 'ледяными', 'егор']
# мгновенно стали ледяными егор
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 3
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 951us/step - loss: 7.0794 - acc: 0.0280 - val_loss: 8.2996 - val_acc: 0.0285
# Generating from seed: ['не', 'выжить', 'и', 'вдруг']
# не выжить и вдруг
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 4
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 7s 905us/step - loss: 7.0160 - acc: 0.0270 - val_loss: 8.5005 - val_acc: 0.0280
# Generating from seed: ['мертвенным', 'синеватым', 'светом', 'юноша']
# мертвенным синеватым светом юноша
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 5
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 997us/step - loss: 6.9577 - acc: 0.0290 - val_loss: 8.4237 - val_acc: 0.0280
# Generating from seed: ['регистрационную', 'печать', 'голубой', 'оттиск']
# регистрационную печать голубой оттиск
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 6
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 6.8956 - acc: 0.0294 - val_loss: 8.2721 - val_acc: 0.0270
# Generating from seed: ['у', 'которого', 'выдернули', 'из']
# у которого выдернули из
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 7
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 989us/step - loss: 6.8382 - acc: 0.0289 - val_loss: 8.0430 - val_acc: 0.0275
# Generating from seed: ['покосился', 'назад', 'уже', 'минуты']
# покосился назад уже минуты
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 8
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 7s 934us/step - loss: 6.7860 - acc: 0.0294 - val_loss: 8.1075 - val_acc: 0.0240
# Generating from seed: ['себя', 'не', 'отвечаю', 'быстро']
# себя не отвечаю быстро
# в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в
# ==================================================
# Iteration #: 9
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 6.7279 - acc: 0.0304 - val_loss: 8.2642 - val_acc: 0.0265
# Generating from seed: ['думать', 'говорить', 'мечтать', 'что']
# думать говорить мечтать что
# не и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и
# ==================================================
# Iteration #: 10
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 985us/step - loss: 6.6642 - acc: 0.0316 - val_loss: 8.4806 - val_acc: 0.0275
# Generating from seed: ['час', 'два', 'максимум', 'на']
# час два максимум на
# не не и в не и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и
# ==================================================
# Iteration #: 11
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 6.5911 - acc: 0.0324 - val_loss: 8.6169 - val_acc: 0.0245
# Generating from seed: ['к', 'беде', 'идущий', 'рядом']
# к беде идущий рядом
# и и и в и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и
# ==================================================
# Iteration #: 12
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 6.5193 - acc: 0.0334 - val_loss: 8.7616 - val_acc: 0.0225
# Generating from seed: ['судить', 'адвокат', 'обвинение', 'все']
# судить адвокат обвинение все
# не и и в в к к и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и
# ==================================================
# Iteration #: 13
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 6.4526 - acc: 0.0350 - val_loss: 8.9091 - val_acc: 0.0225
# Generating from seed: ['вампиров', 'не', 'почувствовал', 'продолжил']
# вампиров не почувствовал продолжил
# я не к и и в и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и
# ==================================================
# Iteration #: 14
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 6.3900 - acc: 0.0375 - val_loss: 9.0142 - val_acc: 0.0260
# Generating from seed: ['много', 'лет', 'назад', 'мне']
# много лет назад мне
# к не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 15
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 959us/step - loss: 6.3281 - acc: 0.0429 - val_loss: 8.9200 - val_acc: 0.0235
# Generating from seed: ['я', 'вот', 'только', 'съем']
# я вот только съем
# и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и
# ==================================================
# Iteration #: 16
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 6.2655 - acc: 0.0409 - val_loss: 9.0210 - val_acc: 0.0225
# Generating from seed: ['тобой', 'работать', 'вот', 'в']
# тобой работать вот в
# не его но но не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 17
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 6.1933 - acc: 0.0441 - val_loss: 9.0002 - val_acc: 0.0245
# Generating from seed: ['какого', 'я', 'уже', 'лет']
# какого я уже лет
# не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 18
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 6.1156 - acc: 0.0464 - val_loss: 9.0088 - val_acc: 0.0205
# Generating from seed: ['это', 'задача', 'для', 'высшего']
# это задача для высшего
# и и не не его но но не мог но не было но но но и не мог но не было но но но и не мог но не было но но но и не мог но не было но но но и не мог но не было но но но и не мог но не было но но но и не мог но не было но но но и не мог но не было но но но и не мог но не было но но но и не мог но не было но но но и не мог но
# ==================================================
# Iteration #: 19
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 994us/step - loss: 6.0304 - acc: 0.0490 - val_loss: 9.1089 - val_acc: 0.0230
# Generating from seed: ['я', 'уже', 'готов', 'был']
# я уже готов был
# и вы состава и еще к холодной за мы что и его но и его что не пользуюсь и его но к пользуюсь и его за снова за его и его что и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его и его
# ==================================================
# Iteration #: 20
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 991us/step - loss: 5.9337 - acc: 0.0539 - val_loss: 9.1139 - val_acc: 0.0195
# Generating from seed: ['долго', 'был', 'человеком', 'и']
# долго был человеком и
# переходу и на не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не
# ==================================================
# Iteration #: 21
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 5.8337 - acc: 0.0534 - val_loss: 9.2273 - val_acc: 0.0230
# Generating from seed: ['на', 'бегу', 'пнул', 'ссохшийся']
# на бегу пнул ссохшийся
# инферно в мог не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не
# ==================================================
# Iteration #: 22
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 969us/step - loss: 5.7307 - acc: 0.0590 - val_loss: 9.2168 - val_acc: 0.0210
# Generating from seed: ['же', 'не', 'идет', 'сильнее']
# же не идет сильнее
# с паре работе алиса вихрю к самой к переходу что сказал я не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не
# ==================================================
# Iteration #: 23
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 998us/step - loss: 5.6301 - acc: 0.0613 - val_loss: 9.3533 - val_acc: 0.0235
# Generating from seed: ['пять', 'лет', 'назад', 'когда']
# пять лет назад когда
# на подворотню но его и и мог и его что не заметил что не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но
# ==================================================
# Iteration #: 24
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 5.5273 - acc: 0.0689 - val_loss: 9.4051 - val_acc: 0.0225
# Generating from seed: ['если', 'ольга', 'могла', 'общаться']
# если ольга могла общаться
# посмотрел и на ним но что не мог но но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но

# %%
print(eval_model(model))
# Out:
# 578312.1447032659

# %% [markdown]
# > Следует сказать, что сгенерированный текст выглядит неплохо для такого малого объема входных данных. Видно, что в какой-то момент генератор "сбивается" и начинает повторяться, но начальные строки в целом выглядят интересно.

# %% [markdown]
# ## GRU

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 128
NUM_ITERATIONS = 40
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100

model_1 = Sequential()
model_1.add(Embedding(nb_chars, 100, input_length=SEQLEN))
model_1.add(GRU(HIDDEN_SIZE, return_sequences=False,
                    input_shape=(SEQLEN, nb_chars),
                    unroll=True))
model_1.add(Dense(nb_chars))
model_1.add(Activation("softmax"))

model_1.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=['acc'])
model_1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 4, 100)            407000
# _________________________________________________________________
# gru_4 (GRU)                  (None, 128)               87936
# _________________________________________________________________
# dense_5 (Dense)              (None, 4070)              525030
# _________________________________________________________________
# activation_5 (Activation)    (None, 4070)              0
# =================================================================
# Total params: 1,019,966
# Trainable params: 1,019,966
# Non-trainable params: 0
# _________________________________________________________________

# %%
for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model_1.fit(Xtrain, Ytrain, validation_data=[Xval, Yval], batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    
    test_idx = np.random.randint(len(train_chars))
    test_chars = train_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(' '.join(test_chars))
    for i in range(NUM_PREDS_PER_EPOCH):
        test_seq = np.zeros((1, SEQLEN))
        for i, ch in enumerate(test_chars):
            test_seq[0, i] = char2index[ch]
        pred = model_1.predict(test_seq, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print(ypred, end=" ")
        test_chars = test_chars[1:] + [ypred]
    print()
# Out:
# ==================================================
# Iteration #: 0
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 7.7786 - acc: 0.0245 - val_loss: 7.6076 - val_acc: 0.0290
# Generating from seed: ['попытаться', 'но', 'не', 'сейчас']
# попытаться но не сейчас
# не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 1
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 7s 938us/step - loss: 7.2475 - acc: 0.0269 - val_loss: 7.8732 - val_acc: 0.0285
# Generating from seed: ['неделя', 'подготовки', 'не', 'прошла']
# неделя подготовки не прошла
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 2
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 980us/step - loss: 7.1570 - acc: 0.0268 - val_loss: 8.1868 - val_acc: 0.0285
# Generating from seed: ['никогда', 'не', 'станет', 'только']
# никогда не станет только
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 3
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 986us/step - loss: 7.0889 - acc: 0.0291 - val_loss: 8.6198 - val_acc: 0.0290
# Generating from seed: ['видеокамере', 'когда', 'переключаешься', 'с']
# видеокамере когда переключаешься с
# не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 4
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 7.0304 - acc: 0.0290 - val_loss: 8.6039 - val_acc: 0.0275
# Generating from seed: ['способны', 'вампиры', 'оборотни', 'темные']
# способны вампиры оборотни темные
# я я не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 5
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.9677 - acc: 0.0298 - val_loss: 8.3236 - val_acc: 0.0305
# Generating from seed: ['руками', 'как', 'нам', 'работать']
# руками как нам работать
# я я не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 6
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 12s 2ms/step - loss: 6.8906 - acc: 0.0320 - val_loss: 8.2391 - val_acc: 0.0295
# Generating from seed: ['на', 'гололеде', 'да', 'так']
# на гололеде да так
# я не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 7
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 6.8150 - acc: 0.0333 - val_loss: 8.3302 - val_acc: 0.0355
# Generating from seed: ['мальчика', 'с', 'закрытыми', 'глазами']
# мальчика с закрытыми глазами
# в мог мог не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 8
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 12s 2ms/step - loss: 6.7298 - acc: 0.0348 - val_loss: 8.3515 - val_acc: 0.0290
# Generating from seed: ['ситуации', 'простить', 'вам', 'мелкое']
# ситуации простить вам мелкое
# ларька ларька ларька временами ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька ларька
# ==================================================
# Iteration #: 9
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 6.6446 - acc: 0.0345 - val_loss: 8.3876 - val_acc: 0.0285
# Generating from seed: ['молодой', 'в', 'яркой', 'оранжевой']
# молодой в яркой оранжевой
# и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не мог не мог в мог и не
# ==================================================
# Iteration #: 10
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 6.5525 - acc: 0.0355 - val_loss: 8.4707 - val_acc: 0.0295
# Generating from seed: ['несущихся', 'машин', 'но', 'егор']
# несущихся машин но егор
# не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не
# ==================================================
# Iteration #: 11
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.4702 - acc: 0.0389 - val_loss: 8.5906 - val_acc: 0.0265
# Generating from seed: ['мне', 'показалось', 'что', 'на']
# мне показалось что на
# меня не душе потом и мог и мог не мог его не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог
# ==================================================
# Iteration #: 12
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 6.3829 - acc: 0.0398 - val_loss: 8.7133 - val_acc: 0.0265
# Generating from seed: ['своей', 'памяти', 'сова', 'расправила']
# своей памяти сова расправила
# и не мог мог не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не
# ==================================================
# Iteration #: 13
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 6.3034 - acc: 0.0405 - val_loss: 8.7322 - val_acc: 0.0260
# Generating from seed: ['на', 'ножках', 'его', 'дома']
# на ножках его дома
# на the начале сообразил на самой его спросил на сумрак но не мог мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог
# ==================================================
# Iteration #: 14
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 6.2246 - acc: 0.0450 - val_loss: 8.8023 - val_acc: 0.0270
# Generating from seed: ['чтобы', 'жить', 'тебе', 'нужна']
# чтобы жить тебе нужна
# не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог
# ==================================================
# Iteration #: 15
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 6.1441 - acc: 0.0490 - val_loss: 8.9189 - val_acc: 0.0240
# Generating from seed: ['след', 'черной', 'воронки', 'становилось']
# след черной воронки становилось
# неужели юноша я чем попытку мы не мог но не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не
# ==================================================
# Iteration #: 16
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.0610 - acc: 0.0503 - val_loss: 8.9309 - val_acc: 0.0210
# Generating from seed: ['костя', 'если', 'для', 'для']
# костя если для для
# мог но не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог
# ==================================================
# Iteration #: 17
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.9769 - acc: 0.0530 - val_loss: 9.0249 - val_acc: 0.0215
# Generating from seed: ['каков', 'ты', 'есть', 'на']
# каков ты есть на
# меня плече среди совы потом игнатьевич над над the no the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# ==================================================
# Iteration #: 18
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.8906 - acc: 0.0563 - val_loss: 9.0720 - val_acc: 0.0235
# Generating from seed: ['вампира', 'мальчик', 'на', 'свете']
# вампира мальчик на свете
# плече перешел в них плече мог можно с мог но что не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не
# ==================================================
# Iteration #: 19
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 5.7948 - acc: 0.0622 - val_loss: 9.0541 - val_acc: 0.0225
# Generating from seed: ['предвкушении', 'добычи', 'опустели', 'их']
# предвкушении добычи опустели их
# юноша раньше онемели их утром на меня плече мог мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог
# ==================================================
# Iteration #: 20
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 5.7014 - acc: 0.0700 - val_loss: 9.0393 - val_acc: 0.0225
# Generating from seed: ['дома', 'медленно', 'словно', 'внезапно']
# дома медленно словно внезапно
# онемели начнется юноша на самом вся антон с душе спросил в них была мог мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не мог не
# ==================================================
# Iteration #: 21
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 5.6139 - acc: 0.0757 - val_loss: 8.9938 - val_acc: 0.0190
# Generating from seed: ['было', 'холодно', 'батареи', 'чуть']
# было холодно батареи чуть
# no no the no the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# ==================================================
# Iteration #: 22
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 5.5207 - acc: 0.0838 - val_loss: 9.0035 - val_acc: 0.0215
# Generating from seed: ['вчетвером', 'мальчик', 'впереди', 'за']
# вчетвером мальчик впереди за
# девушки среди никак в подземный спросил в сумрак и мог почти его и за шефа но он мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог
# ==================================================
# Iteration #: 23
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 5.4269 - acc: 0.0948 - val_loss: 8.9508 - val_acc: 0.0220
# Generating from seed: ['секунду', 'медлил', 'пытаясь', 'придумать']
# секунду медлил пытаясь придумать
# назад поутихло я того не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не
# ==================================================
# Iteration #: 24
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 5.3377 - acc: 0.1038 - val_loss: 8.8511 - val_acc: 0.0220
# Generating from seed: ['антон', 'гостиница', 'космос', 'рядом']
# антон гостиница космос рядом
# девушка на лице спросил в сумрак появился что ты было не мог спросил что я хотел спросил в прихожую метро и них было амулет с ней спросил а я хотел спросил в прихожую метро и них было амулет с ней спросил а я хотел спросил в прихожую метро и них было амулет с ней спросил а я хотел спросил в прихожую метро и них было амулет с ней спросил а я хотел спросил в прихожую метро и них было амулет с ней спросил а я хотел спросил в прихожую метро и них было амулет с ней спросил а я хотел
# ==================================================
# Iteration #: 25
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.2500 - acc: 0.1103 - val_loss: 8.9564 - val_acc: 0.0210
# Generating from seed: ['в', 'воздушном', 'поцелуе', 'тихо']
# в воздушном поцелуе тихо
# мы не расслабилось но шеф уже разрядил его и не приукрасил но шеф не улицах но в успех заметил а в метро был с ней сторону что я выполнял мимо девушки под нее будто не мог вампира его что не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не
# ==================================================
# Iteration #: 26
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.1624 - acc: 0.1228 - val_loss: 8.8410 - val_acc: 0.0210
# Generating from seed: ['несколько', 'секунд', 'тот', 'ждал']
# несколько секунд тот ждал
# с расстоянии плече мимо задания с нее плече вампирша крылья в сумрак и быть к ней плече его крылья что я не мог его что не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог не мог но не мог
# ==================================================
# Iteration #: 27
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.0728 - acc: 0.1349 - val_loss: 8.8383 - val_acc: 0.0215
# Generating from seed: ['и', 'машина', 'отъехала', 'от']
# и машина отъехала от
# сумрака будто вампиры другой них навстречу были защитную к ним начале сообразил в подворотню грани иди не было было как мог мог его что не мог но что не мог спросил что я видел был он уже не мог что его что как мог мог его что не мог но что не мог спросил что я видел был он уже не мог что его что как мог мог его что не мог но что не мог спросил что я видел был он уже не мог что его что как мог мог его что не мог но что не мог спросил
# ==================================================
# Iteration #: 28
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 4.9832 - acc: 0.1479 - val_loss: 8.8446 - val_acc: 0.0175
# Generating from seed: ['в', 'карман', 'я', 'коснулся']
# в карман я коснулся
# мимо цель дневной feel вчера антон над над посмотрел из сумрака на ванную спросил а я выполнял редко потом темно мешок я стал чем антон с нее мира способствующий шефа вампира одной не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог
# ==================================================
# Iteration #: 29
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 4.8966 - acc: 0.1615 - val_loss: 8.8492 - val_acc: 0.0190
# Generating from seed: ['как', 'положено', 'положено', 'не']
# как положено положено не
# мог не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но
# ==================================================
# Iteration #: 30
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 4.8087 - acc: 0.1781 - val_loss: 8.7726 - val_acc: 0.0195
# Generating from seed: ['либо', 'войти', 'в', 'ступор']
# либо войти в ступор
# плече уже уже для мог спросил что я видел спросил на меня была был слишком мог что как как мог мог его что не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог
# ==================================================
# Iteration #: 31
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 4.7221 - acc: 0.1886 - val_loss: 8.7775 - val_acc: 0.0190
# Generating from seed: ['угадал', 'или', 'нет', 'визуально']
# угадал или нет визуально
# в меня он мог что что он мог но он мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не
# ==================================================
# Iteration #: 32
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 4.6298 - acc: 0.2077 - val_loss: 8.8204 - val_acc: 0.0180
# Generating from seed: ['будут', 'весьма', 'удивлены', 'полярная']
# будут весьма удивлены полярная
# я не было спросил что вот заполняла идти что вот сам для мог но что не мог спросил что вот сам идти что я сам спросил что вот остается от заглядывая метро в сумрак или амулет а для моем мог и как не мог что что его как интереснее что за дозор к них к нее тоже такой никак а ты не мог но что не мог спросил что вот сам идти что я сам спросил что вот остается от заглядывая метро в сумрак или амулет а для моем мог и как не мог что что его как интереснее что
# ==================================================
# Iteration #: 33
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 4.5418 - acc: 0.2207 - val_loss: 8.7915 - val_acc: 0.0230
# Generating from seed: ['проходила', 'он', 'даже', 'обернулся']
# проходила он даже обернулся
# не отвечаю но это не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но
# ==================================================
# Iteration #: 34
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 4.4573 - acc: 0.2355 - val_loss: 8.7708 - val_acc: 0.0215
# Generating from seed: ['повезет', 'в', 'квартире', 'было']
# повезет в квартире было
# за пошел но шеф уже для мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог
# ==================================================
# Iteration #: 35
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 4.3704 - acc: 0.2579 - val_loss: 8.7699 - val_acc: 0.0205
# Generating from seed: ['и', 'таинственным', 'шепотом', 'произнес']
# и таинственным шепотом произнес
# и не мог не мог что что его как одной а как за лишь к утру к нее был за расправила к шефа я сумрака мимо его дневной дозор и девушки антон с сову спросил в сумрак них за ней спросил из них силой за вздохнул прошел да шеф дозор к мог к нее к шефа тоже можно спросил я был связь и все вокруг отступать цель другой вчера навстречу сова имею крыльями я был если как до сих но слишком мог не мог но не мог но не мог но не мог но не мог но не мог но
# ==================================================
# Iteration #: 36
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 9s 1ms/step - loss: 4.2841 - acc: 0.2736 - val_loss: 8.7875 - val_acc: 0.0200
# Generating from seed: ['зафиксировал', 'движение', 'мальчик', 'нырнул']
# зафиксировал движение мальчик нырнул
# в метро геннадий за руку к него стоял возник в меховом спросил за пошел будто глаза и того к ней тоже его спросил я был был был он ним но шеф же но не страшное спросил что вот же идти я смотрел на мальчика на ходу плече перешел а я почувствовал спросил в стороне попытку мало с такой силой но мы же спросил я побежал бросил лишь и пусть с ходу мог спросил я был бросил идти в подворотню и уже не мог что не мог но не мог но не мог но не мог но не мог но не
# ==================================================
# Iteration #: 37
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 4.1946 - acc: 0.2918 - val_loss: 8.7700 - val_acc: 0.0210
# Generating from seed: ['вчера', 'ты', 'показал', 'свое']
# вчера ты показал свое
# женщина улыбнулась ее и так вампира явно и раз к месту вампира его не было но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но
# ==================================================
# Iteration #: 38
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 1ms/step - loss: 4.1075 - acc: 0.3075 - val_loss: 8.7595 - val_acc: 0.0210
# Generating from seed: ['проклятие', 'дело', 'даже', 'не']
# проклятие дело даже не
# в ней плече перешел а и уже идти что ты было спросил что вот остается егор современные до вампиры навстречу борис антон антон и силы чтобы сказал что устным он было следом от них вампира охота и обычно а такой глава были шефа ко них я не мог может не мог что что его как одной а как за ним у них людей за шефа к полуночи я бросил прошел но ты было но что его что как как раз а дневной дозор к окну под не мог что не мог но что не мог спросил я выскочил на мальчика
# ==================================================
# Iteration #: 39
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 8s 988us/step - loss: 4.0224 - acc: 0.3229 - val_loss: 8.7736 - val_acc: 0.0205
# Generating from seed: ['вот', 'это', 'сопротивляемость', 'зов']
# вот это сопротивляемость зов
# а с нее к шефа сторону девушка за лишь ситуация сова никак не мог мог не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не мог но не

# %%
print(eval_model(model_1))
# Out:
# 163095.09653006427

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 64
NUM_ITERATIONS = 40
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100

model_1 = Sequential()
model_1.add(Embedding(nb_chars, 100, input_length=SEQLEN))
model_1.add(GRU(HIDDEN_SIZE, return_sequences=False,
                    input_shape=(SEQLEN, nb_chars),
                    unroll=True))
model_1.add(Dense(nb_chars))
model_1.add(Activation("softmax"))

model_1.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=['acc'])
model_1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, 4, 100)            407000
# _________________________________________________________________
# gru_5 (GRU)                  (None, 128)               87936
# _________________________________________________________________
# dense_6 (Dense)              (None, 4070)              525030
# _________________________________________________________________
# activation_6 (Activation)    (None, 4070)              0
# =================================================================
# Total params: 1,019,966
# Trainable params: 1,019,966
# Non-trainable params: 0
# _________________________________________________________________

# %%
for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model_1.fit(Xtrain, Ytrain, validation_data=[Xval, Yval], batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    
    test_idx = np.random.randint(len(train_chars))
    test_chars = train_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(' '.join(test_chars))
    for i in range(NUM_PREDS_PER_EPOCH):
        test_seq = np.zeros((1, SEQLEN))
        for i, ch in enumerate(test_chars):
            test_seq[0, i] = char2index[ch]
        pred = model_1.predict(test_seq, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print(ypred, end=" ")
        test_chars = test_chars[1:] + [ypred]
    print()
# Out:
# ==================================================
# Iteration #: 0
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 12s 1ms/step - loss: 7.6902 - acc: 0.0274 - val_loss: 7.6552 - val_acc: 0.0225
# Generating from seed: ['это', 'время', 'придется', 'найти']
# это время придется найти
# в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в в
# ==================================================
# Iteration #: 1
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 7.2793 - acc: 0.0281 - val_loss: 7.8652 - val_acc: 0.0285
# Generating from seed: ['достаточно', 'компактном', 'еще', 'плеер']
# достаточно компактном еще плеер
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 2
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 7.1635 - acc: 0.0289 - val_loss: 7.9413 - val_acc: 0.0285
# Generating from seed: ['блеснули', 'длинные', 'уже', 'нечеловеческие']
# блеснули длинные уже нечеловеческие
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 3
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 7.0453 - acc: 0.0294 - val_loss: 8.0834 - val_acc: 0.0280
# Generating from seed: ['язык', 'сова', 'смотрела', 'на']
# язык сова смотрела на
# не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не не
# ==================================================
# Iteration #: 4
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.9262 - acc: 0.0326 - val_loss: 8.0167 - val_acc: 0.0320
# Generating from seed: ['именно', 'он', 'инициировал', 'девушку']
# именно он инициировал девушку
# я не не мог и и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в сумрак и не мог и не не меня в
# ==================================================
# Iteration #: 5
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.8228 - acc: 0.0353 - val_loss: 8.0410 - val_acc: 0.0300
# Generating from seed: ['которого', 'пластами', 'сходила', 'кожа']
# которого пластами сходила кожа
# the болеть щеки щеки и не не меня и и и не мог и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и и
# ==================================================
# Iteration #: 6
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 6.7117 - acc: 0.0378 - val_loss: 8.0771 - val_acc: 0.0285
# Generating from seed: ['них', 'я', 'позволил', 'себе']
# них я позволил себе
# и не самом и и и меня и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог и и и не мог
# ==================================================
# Iteration #: 7
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.6165 - acc: 0.0383 - val_loss: 8.1340 - val_acc: 0.0305
# Generating from seed: ['ну', 'что', 'страшного', 'в']
# ну что страшного в
# самом дом и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не мог и не
# ==================================================
# Iteration #: 8
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.5309 - acc: 0.0413 - val_loss: 8.1528 - val_acc: 0.0290
# Generating from seed: ['вышел', 'в', 'прихожую', 'принялся']
# вышел в прихожую принялся
# мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог но и не мог мог и не мог
# ==================================================
# Iteration #: 9
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.4621 - acc: 0.0400 - val_loss: 8.2552 - val_acc: 0.0290
# Generating from seed: ['но', 'надо', 'какая', 'реальность']
# но надо какая реальность
# я не мог мог не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не мог не мог и не
# ==================================================
# Iteration #: 10
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.3787 - acc: 0.0458 - val_loss: 8.2619 - val_acc: 0.0300
# Generating from seed: ['удивленно', 'посмотрел', 'на', 'меня']
# удивленно посмотрел на меня
# не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог мог мог не мог но не мог
# ==================================================
# Iteration #: 11
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.2864 - acc: 0.0504 - val_loss: 8.4353 - val_acc: 0.0285
# Generating from seed: ['смело', 'начисто', 'пожилая', 'женщина']
# смело начисто пожилая женщина
# юноша pain онемели я отклик онемели и одобрен одобрен я не знаю мог и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог
# ==================================================
# Iteration #: 12
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.1870 - acc: 0.0559 - val_loss: 8.3796 - val_acc: 0.0245
# Generating from seed: ['своей', 'удачи', 'не', 'понимаешь']
# своей удачи не понимаешь
# и не мог меня его не мог мог меня не мог но и мог не мог но не мог меня его не мог мог меня не мог но и мог не мог но не мог меня его не мог мог меня не мог но и мог не мог но не мог меня его не мог мог меня не мог но и мог не мог но не мог меня его не мог мог меня не мог но и мог не мог но не мог меня его не мог мог меня не мог но и мог не мог но не мог меня
# ==================================================
# Iteration #: 13
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 6.0840 - acc: 0.0607 - val_loss: 8.4297 - val_acc: 0.0255
# Generating from seed: ['их', 'сумраке', 'я', 'не']
# их сумраке я не
# не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и не мог но и
# ==================================================
# Iteration #: 14
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.9821 - acc: 0.0665 - val_loss: 8.5500 - val_acc: 0.0290
# Generating from seed: ['помощи', 'не', 'требуется', 'плохо']
# помощи не требуется плохо
# в сумрак я не мог но что в сумрак не мог его его не мог но и не мог но что в сумрак не мог его его не мог но и не мог но что в сумрак не мог его его не мог но и не мог но что в сумрак не мог его его не мог но и не мог но что в сумрак не мог его его не мог но и не мог но что в сумрак не мог его его не мог но и не мог но что в сумрак не мог его его не мог но
# ==================================================
# Iteration #: 15
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.8822 - acc: 0.0729 - val_loss: 8.5202 - val_acc: 0.0295
# Generating from seed: ['брошенная', 'сове', 'напоследок', 'извините']
# брошенная сове напоследок извините
# я не было не мог но что в сумрак не мог его его не мог но что в сумрак не мог его его не мог но что в сумрак не мог его его не мог но что в сумрак не мог его его не мог но что в сумрак не мог его его не мог но что в сумрак не мог его его не мог но что в сумрак не мог его его не мог но что в сумрак не мог его его не мог но что в сумрак не мог его его не мог но что в сумрак не
# ==================================================
# Iteration #: 16
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 5.7806 - acc: 0.0863 - val_loss: 8.4232 - val_acc: 0.0265
# Generating from seed: ['здесь', 'до', 'сих', 'пор']
# здесь до сих пор
# красивая смерч света пор к окну среди поднялся мы клыков на самом и за них среди вы по одобрен под сова его но не мог но меня меня меня меня раз по ночного среди среди руку в сумрак вернее но ты него него мог его его не мог но меня меня меня меня раз по ночного среди среди руку в сумрак вернее но ты него него мог его его не мог но меня меня меня меня раз по ночного среди среди руку в сумрак вернее но ты него него мог его его не мог но меня меня меня меня раз
# ==================================================
# Iteration #: 17
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 5.6800 - acc: 0.0962 - val_loss: 8.4625 - val_acc: 0.0280
# Generating from seed: ['просил', 'о', 'новой', 'апелляции']
# просил о новой апелляции
# антон клыков к сумрак к месту не мог его не мог но меня меня как но раз что но меня раз но не мог его меня меня не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не мог но ты не
# ==================================================
# Iteration #: 18
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 5.5841 - acc: 0.1063 - val_loss: 8.4728 - val_acc: 0.0260
# Generating from seed: ['о', 'балансе', 'сил', 'это']
# о балансе сил это
# с чем тебе перешел но я не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты
# ==================================================
# Iteration #: 19
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 11s 1ms/step - loss: 5.4919 - acc: 0.1239 - val_loss: 8.4351 - val_acc: 0.0250
# Generating from seed: ['не', 'в', 'ней', 'дело']
# не в ней дело
# не в ней но не мог но меня меня как как вопрос что его его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его не мог но ты его
# ==================================================
# Iteration #: 20
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.4047 - acc: 0.1397 - val_loss: 8.4831 - val_acc: 0.0250
# Generating from seed: ['приведет', 'к', 'беде', 'идущий']
# приведет к беде идущий
# не мог его его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его не мог но его
# ==================================================
# Iteration #: 21
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7996/7996 [==============================] - 10s 1ms/step - loss: 5.3143 - acc: 0.1510 - val_loss: 8.4097 - val_acc: 0.0235
# Generating from seed: ['ответа', 'даже', 'если', 'ольга']
# ответа даже если ольга
# для шефа и же как как почти почти тебе жить к ней не мог но ты его что как не мог но его не мог но ты его что как не мог но его не мог но ты его что как не мог но его не мог но ты его что как не мог но его не мог но ты его что как не мог но его не мог но ты его что как не мог но его не мог но ты его что как не мог но его не мог но ты его что как не мог но его
# ==================================================
# Iteration #: 22
# Train on 7996 samples, validate on 2000 samples
# Epoch 1/1
# 7936/7996 [============================>.] - ETA: 0s - loss: 5.2217 - acc: 0.1702

# %%
print(eval_model(model_1))

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 64
NUM_ITERATIONS = 30
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100
SEQLEN = 10  #попробуем с бОльшим размером последовательности

model_1 = Sequential()
model_1.add(Embedding(nb_chars, 100, input_length=SEQLEN))
model_1.add(GRU(HIDDEN_SIZE, return_sequences=False,
                    input_shape=(SEQLEN, nb_chars),
                    unroll=True))
model_1.add(Dense(nb_chars))
model_1.add(Activation("softmax"))

model_1.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=['acc'])
model_1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 10, 100)           407000
# _________________________________________________________________
# gru_3 (GRU)                  (None, 128)               87936
# _________________________________________________________________
# dense_3 (Dense)              (None, 4070)              525030
# _________________________________________________________________
# activation_3 (Activation)    (None, 4070)              0
# =================================================================
# Total params: 1,019,966
# Trainable params: 1,019,966
# Non-trainable params: 0
# _________________________________________________________________

# %%
for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" % (iteration))
    model_1.fit(Xtrain, Ytrain, validation_data=[Xval, Yval], batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    
    test_idx = np.random.randint(len(train_chars))
    test_chars = train_chars[test_idx]
    print("Generating from seed: %s" % (test_chars))
    print(' '.join(test_chars))
    for i in range(NUM_PREDS_PER_EPOCH):
        test_seq = np.zeros((1, SEQLEN))
        for i, ch in enumerate(test_chars):
            test_seq[0, i] = char2index[ch]
        pred = model_1.predict(test_seq, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print(ypred, end=" ")
        test_chars = test_chars[1:] + [ypred]
    print()
# Out:
# ==================================================
# Iteration #: 0
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 14s 2ms/step - loss: 7.6918 - acc: 0.0268 - val_loss: 7.6981 - val_acc: 0.0295
# Generating from seed: ['отвечаю', 'быстро', 'сказал', 'я', 'обрывая', 'связь', 'и', 'остановился', 'перед', 'милицейским']
# отвечаю быстро сказал я обрывая связь и остановился перед милицейским
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 1
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 1ms/step - loss: 7.3006 - acc: 0.0262 - val_loss: 7.8791 - val_acc: 0.0295
# Generating from seed: ['лилась', 'музыка', 'тихая', 'едва', 'слышная', 'но', 'удивительно', 'приятная', 'тонкое', 'пение']
# лилась музыка тихая едва слышная но удивительно приятная тонкое пение
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 2
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 11s 1ms/step - loss: 7.1823 - acc: 0.0289 - val_loss: 7.9598 - val_acc: 0.0300
# Generating from seed: ['дай', 'нам', 'минутку', 'птица', 'не', 'отреагировала', 'а', 'вот', 'костя', 'переводил']
# дай нам минутку птица не отреагировала а вот костя переводил
# я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я я
# ==================================================
# Iteration #: 3
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 2ms/step - loss: 7.0625 - acc: 0.0299 - val_loss: 8.0960 - val_acc: 0.0360
# Generating from seed: ['они', 'чуть', 'не', 'прикончили', 'мальчишку', 'просто', 'так', 'не', 'от', 'голода']
# они чуть не прикончили мальчишку просто так не от голода
# я не не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня я не меня
# ==================================================
# Iteration #: 4
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 2ms/step - loss: 6.9644 - acc: 0.0330 - val_loss: 7.9553 - val_acc: 0.0355
# Generating from seed: ['the', 'shadow', 'of', 'the', 'moon', 'she', 'danced', 'in', 'the', 'starlight']
# the shadow of the moon she danced in the starlight
# на окрашивающееся окрашивающееся переносят окрашивающееся переносят окрашивающееся переносят в меховом праве меня в сумрак в сумрак в меня в меховом меня в меховом меня в подворотню в сумрак в сумрак в подворотню в меховом меня в меховом меня в сумрак в меня в подворотню в подворотню в меховом меня в сумрак в сумрак в подворотню в подворотню в меховом меня в сумрак в сумрак в подворотню в подворотню в меховом меня в сумрак в сумрак в подворотню в подворотню в меховом меня в сумрак в сумрак в подворотню в подворотню в меховом меня в сумрак в сумрак в подворотню в
# ==================================================
# Iteration #: 5
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 2ms/step - loss: 6.8669 - acc: 0.0352 - val_loss: 7.9877 - val_acc: 0.0310
# Generating from seed: ['реальности', 'в', 'другую', 'первой', 'неожиданностью', 'было', 'то', 'что', 'парочка', 'оказалась']
# реальности в другую первой неожиданностью было то что парочка оказалась
# в сумрак я среди в неслись среди среди среди в ближних неслись среди ждал на ближних неслись среди в проспекта среди среди среди на ждал ждал ждал первая feel первая добраться на добраться на первая запрос запрос запрос ждал в проспекта и среди в неслись среди среди среди ждал на спешащая ждал feel feel feel первая добраться feel feel feel добраться добраться добраться feel добраться feel feel добраться feel feel feel добраться добраться добраться feel добраться feel feel добраться feel feel feel добраться добраться добраться feel добраться feel feel добраться feel feel feel добраться добраться добраться feel добраться feel feel
# ==================================================
# Iteration #: 6
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 2ms/step - loss: 6.7740 - acc: 0.0360 - val_loss: 8.0220 - val_acc: 0.0340
# Generating from seed: ['глаза', 'я', 'мог', 'наблюдать', 'картину', 'более', 'занятную', 'блеклые', 'как', 'обычно']
# глаза я мог наблюдать картину более занятную блеклые как обычно
# не меня и в морозный среди среди среди в морозный и среди в портрету среди среди и в душе или или чем и не повинных и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак и не сумрак
# ==================================================
# Iteration #: 7
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 2ms/step - loss: 6.6936 - acc: 0.0378 - val_loss: 7.9781 - val_acc: 0.0230
# Generating from seed: ['отставил', 'бутылочку', 'потом', 'передумав', 'наклонил', 'ее', 'над', 'раковиной', 'нам', 'не']
# отставил бутылочку потом передумав наклонил ее над раковиной нам не
# меня и от подходящую среди среди среди и к портрету среди среди среди среди среди среди от среди среди среди the трепал the the трепал среди среди среди среди от среди среди среди среди the трепал the the трепал среди среди среди среди от среди среди среди среди the трепал the the трепал среди среди среди среди от среди среди среди среди the трепал the the трепал среди среди среди среди от среди среди среди среди the трепал the the трепал среди среди среди среди от среди среди среди среди the трепал the the трепал среди среди среди среди от
# ==================================================
# Iteration #: 8
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 1ms/step - loss: 6.6184 - acc: 0.0412 - val_loss: 8.0685 - val_acc: 0.0280
# Generating from seed: ['задремывая', 'позволяя', 'сознанию', 'отдохнуть', 'а', 'чувствам', 'раскрепостится', 'все', 'было', 'глухо']
# задремывая позволяя сознанию отдохнуть а чувствам раскрепостится все было глухо
# не меня не сумрак и в плеером людей или или более стекала или чем я чем я чем и более стекала людей и более сумрак людей в москве сторону или или чем в москве стекала или или чем в сумрак людей или в москве стекала или или более чем и не сумрак или чем и более стекала людей или чем в плеером людей или не сумрак и чем в портрету людей или чем в плеером людей и не чем и более стекала людей в сумрак или людей или чем в сумрак людей и более стекала и сова более стекала или
# ==================================================
# Iteration #: 9
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 6.5416 - acc: 0.0420 - val_loss: 8.1284 - val_acc: 0.0270
# Generating from seed: ['милость', 'это', 'пернатое', 'создание', 'может', 'мне', 'помочь', 'тебя', 'зовут', 'ольга']
# милость это пернатое создание может мне помочь тебя зовут ольга
# на столе ощущение среди среди в портрету малышом среди среди the danced среди the the портрету the неслись the заднем the дворником среди более среди среди the the портрету the заднем the портрету более стекала и в сумрак была людей или не чем людей сова чем сова более чем или более стекала и в карман среди людей сова сова чем в карман людей или в карман была или или сова чем не чем людей сова чем в карман людей или или сова чем не более стекала и в паре была или сова более более более более более стекала и в
# ==================================================
# Iteration #: 10
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 1ms/step - loss: 6.4724 - acc: 0.0444 - val_loss: 8.2301 - val_acc: 0.0260
# Generating from seed: ['ведь', 'женщина', 'хоть', 'и', 'сова', 'может', 'брюки', 'одеть', 'стою', 'в']
# ведь женщина хоть и сова может брюки одеть стою в
# губам ощущение будто руку и оттягивал лишь от месту спросил и не просто просто просто более более более более более мой сова сова сова чем я чем не просто более более более более мой более более стекала и сова чем не более более более мой сова сова сова сова чем не чем не просто более более более мой сова сова сова сова чем не чем не просто более более более мой сова сова сова сова чем не чем не просто более более более мой сова сова сова сова чем не чем не просто более более более мой сова сова сова
# ==================================================
# Iteration #: 11
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 2ms/step - loss: 6.3949 - acc: 0.0504 - val_loss: 8.1448 - val_acc: 0.0280
# Generating from seed: ['твоих', 'ошибок', 'стоит', 'ли', 'терять', 'время', 'робко', 'спросил', 'я', 'не']
# твоих ошибок стоит ли терять время робко спросил я не
# не мог более более более более более более более более более более повернула сова сова сова сова сова не более более более более более более более более более повернула сова сова сова сова сова не более более более более более более более более более повернула сова сова сова сова сова не более более более более более более более более более повернула сова сова сова сова сова не более более более более более более более более более повернула сова сова сова сова сова не более более более более более более более более более повернула сова сова сова сова сова не более
# ==================================================
# Iteration #: 12
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 6.3152 - acc: 0.0541 - val_loss: 8.2393 - val_acc: 0.0275
# Generating from seed: ['ни', 'слова', 'антон', 'ответь', 'я', 'молчал', 'голос', 'у', 'ларисы', 'деловой']
# ни слова антон ответь я молчал голос у ларисы деловой
# я более более более более более перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более более более более перед перед перед перед перед более
# ==================================================
# Iteration #: 13
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 2ms/step - loss: 6.2434 - acc: 0.0577 - val_loss: 8.2146 - val_acc: 0.0295
# Generating from seed: ['выпитое', 'тело', 'мальчика', 'и', 'исчезающих', 'вампиров', 'но', 'я', 'успел', 'мальчик']
# выпитое тело мальчика и исчезающих вампиров но я успел мальчик
# меня из меня и безумный сова перед перед перед перед перед перед перед более более более перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед
# ==================================================
# Iteration #: 14
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 1ms/step - loss: 6.1647 - acc: 0.0619 - val_loss: 8.3152 - val_acc: 0.0325
# Generating from seed: ['главная', 'беда', 'антон', 'шеф', 'вдруг', 'повернулся', 'бросил', 'испепеляющий', 'взгляд', 'на']
# главная беда антон шеф вдруг повернулся бросил испепеляющий взгляд на
# меня будто руку в карман ощущение тихо девушка и не основной просто перед головой или перед перед перед перед перед перед перед более более перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед
# ==================================================
# Iteration #: 15
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 12s 1ms/step - loss: 6.0849 - acc: 0.0698 - val_loss: 8.2305 - val_acc: 0.0290
# Generating from seed: ['от', 'очередного', 'назойливого', 'коммиявожера', 'и', 'провел', 'реморализацию', 'легкую', 'на', 'самой']
# от очередного назойливого коммиявожера и провел реморализацию легкую на самой
# меня та делу глаза и ждал лишь седьмого седьмого the the the темных сова совершенно сразу перед враг или сова перед перед перед перед перед перед более более более перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед перед
# ==================================================
# Iteration #: 16
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 6.0027 - acc: 0.0752 - val_loss: 8.2757 - val_acc: 0.0300
# Generating from seed: ['принялся', 'торопливо', 'обуваться', 'ты', 'заходи', 'сказал', 'я', 'я', 'не', 'враг']
# принялся торопливо обуваться ты заходи сказал я я не враг
# не видел не видел как в паре миг антон и регистрационная пронзительно не сонным посмотрел и к губам миг рядом рядом на губам ощущение тихо и в месту месту или не просто просто более более более более более перед молодая или или или или или перед перед головой более более более более перед перед перед перед перед головой или или сова перед перед перед перед головой или или сова сова или или перед перед перед более более более более более перед перед перед перед перед перед головой или или сова перед перед перед перед головой или или сова сова или
# ==================================================
# Iteration #: 17
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 5.9132 - acc: 0.0832 - val_loss: 8.3159 - val_acc: 0.0290
# Generating from seed: ['пришлось', 'убивать', 'метка', 'слабо', 'светящаяся', 'голубым', 'печать', 'на', 'груди', 'вампира']
# пришлось убивать метка слабо светящаяся голубым печать на груди вампира
# вы руку в карман ощущение тихо тихо рядом рядом на меня и уже не является в метро метро или или сумрака меня это более головой перед перед перед перед перед перед перед головой или меня и никогда и не хотел мимо перед перед перед перед более его более более более более перед перед перед перед перед головой или сова сова перед сумрака и сова перед перед головой или или или перед перед перед более более более более перед перед перед перед перед перед головой или сова сова сова или или сумрака не перед перед перед более более более перед перед
# ==================================================
# Iteration #: 18
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 5.8296 - acc: 0.0895 - val_loss: 8.2412 - val_acc: 0.0260
# Generating from seed: ['стараясь', 'не', 'показывать', 'зубы', 'за', 'десять', 'с', 'кольцом', 'прыщавый', 'парень']
# стараясь не показывать зубы за десять с кольцом прыщавый парень
# в чем была цель переставая симфонию антон девушка к самой те именно сова самому рядом и в самом во работы и сова всегда лишь посмотрел и у него силой к месту вернее ощущение сова сова чем и впрямь перед видел и сова перед перед перед перед перед перед перед ауры шеф сова сова перед перед перед перед перед перед более более более более перед перед перед перед перед перед перед перед перед перед сумрака сова сова сова перед сумрака или сумрака не обычным перед перед перед перед перед перед более более более более перед перед перед перед перед перед перед
# ==================================================
# Iteration #: 19
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 14s 2ms/step - loss: 5.7390 - acc: 0.1001 - val_loss: 8.2675 - val_acc: 0.0285
# Generating from seed: ['и', 'все', 'таки', 'я', 'должен', 'буду', 'попытаться', 'но', 'не', 'сейчас']
# и все таки я должен буду попытаться но не сейчас
# была цель более мой оперативной антон сова перед перед перед головой или ты не видел антон шеф только перед оперативной перед перед перед оперативной именно ты не просто перед головой перед перед головой более более более перед перед перед головой или сова сова перед перед перед перед перед головой чем ты сова перед оперативной перед перед перед перед перед перед головой чем и сова поезд сказал я бросил моей оперативной оперативной к карман антон именно ты меня была это не видел как шеф без перед враг антон к карман или именно ты сумрака не видел как ты сейчас сказал и
# ==================================================
# Iteration #: 20
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 5.6614 - acc: 0.1132 - val_loss: 8.2331 - val_acc: 0.0285
# Generating from seed: ['было', 'холодно', 'батареи', 'чуть', 'грели', 'единственное', 'за', 'что', 'люблю', 'зиму']
# было холодно батареи чуть грели единственное за что люблю зиму
# быть ощущение будто в карман вампира в карман пластами карман в сумрак чем чем сова карман я видел совершенно совершенно перед без без без перед карман антон к самом при своей именно сова сова сказал и все быть антон я видел и все быть антон и ведьмак поезд как у столе а глаза за миг ни рядом рядом в сумрак ощущение в сумрак как сова сова стекала и все быть антон и сова начал и все впрямь сказал я видел и не хотел перед оперативной перед перед перед перед своей чем шеф ты тоже просто обычным перед перед перед перед
# ==================================================
# Iteration #: 21
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 5.5741 - acc: 0.1219 - val_loss: 8.3605 - val_acc: 0.0255
# Generating from seed: ['я', 'отдам', 'ему', 'початый', 'шкалик', 'я', 'пробежал', 'мимо', 'там', 'другое']
# я отдам ему початый шкалик я пробежал мимо там другое
# его не просто его его не просто просто более более перед перед перед перед более мимо более более более перед перед перед перед более более более более перед перед перед перед более или ты сова перед сумрака сказал я был антон и впрямь не видел как ты был не оперативной перед перед перед перед оперативной но ты не просто просто перед перед перед более более более более перед перед перед перед более или ты сова перед сумрака сказал я был антон и впрямь не видел как ты был не оперативной перед перед перед перед оперативной но ты не просто просто
# ==================================================
# Iteration #: 22
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 5.4889 - acc: 0.1381 - val_loss: 8.2589 - val_acc: 0.0265
# Generating from seed: ['из', 'головы', 'будто', 'выдуло', 'все', 'мысли', 'он', 'уже', 'почти', 'бежал']
# из головы будто выдуло все мысли он уже почти бежал
# нет из сумрака как совершенно сумрака найти сказал я к шефа спросил я уже к месту была шеф сова сова или ты сова сказал я видел сказал я был к оперативной при оперативной антон антон антон ты шефа а ты же антон ты пусть у меня вокруг рядом и полным ведьмак лишь лишь лишь оперативной хуже заданием обычным шефа а ты было сказал ты сова юноша у меня к оперативной сумрака сова сова они или или ты она или или или ты перед оперативной или или ты сумрака или или сумрака они перед шефа сказал я был антон с оперативной
# ==================================================
# Iteration #: 23
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 5.4061 - acc: 0.1478 - val_loss: 8.2566 - val_acc: 0.0260
# Generating from seed: ['здесь', 'рядом', 'может', 'быть', 'я', 'и', 'с', 'вагоном', 'угадал', 'искоса']
# здесь рядом может быть я и с вагоном угадал искоса
# сова ужасом в метро или парень или дозор сказал я мог оперативной к ней была ты сова сова или или ты никогда не видел как это не просто заметил антон шеф шеф которым к утру вот ты уже было сильнее почти сказал шеф ты сова сказал я видел антон я был антон из сумрака сумрака антон и обычный впрямь сказал я видел антон я был лет оперативной к ней при шефа антон ты было антон антон я оперативной оперативной оперативной из сумрака или или ты сумрака не видел шеф шеф сказал я видел антон и все том что я оперативной
# ==================================================
# Iteration #: 24
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 14s 2ms/step - loss: 5.3207 - acc: 0.1600 - val_loss: 8.2176 - val_acc: 0.0275
# Generating from seed: ['подтолкнули', 'его', 'к', 'свету', 'протокол', 'писать', 'будем', 'меня', 'вдруг', 'развеселила']
# подтолкнули его к свету протокол писать будем меня вдруг развеселила
# на меня меня вы теплых ощущение ощущение для миг к месту двери к сумрак рядом это не было разгоняла а ты перед неужели как ты уже была перед головой перед головой или сова ты сова сказал я видел сказал я был к головой при него сова сова ни сказал я не мог мимо перед головой или ты ты меня сказал я был антон к ней при головой сова сова ты они сказал сказал я был не мог была ты меня сказал я был антон к утру антон я был к головой была торопливо неужели и сова начал и все быть
# ==================================================
# Iteration #: 25
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 13s 2ms/step - loss: 5.2344 - acc: 0.1722 - val_loss: 8.2748 - val_acc: 0.0275
# Generating from seed: ['вампира', 'спрятал', 'мешок', 'в', 'багажник', 'из', 'чахлого', 'сугроба', 'оставленного', 'нерадивым']
# вампира спрятал мешок в багажник из чахлого сугроба оставленного нерадивым
# меня набрал но зато у сумрака ощущение ощущение рядом к утру антон девушка на миг меня была меня меня был был был и впрямь жить не видел антон с них антон сова вчера я видел антон которым и у него спросил что ты она спешу но я был и что они перед перед перед вампира сказал я был к миг была себя и впрямь сова ты сова сказал я видел антон и все быть антон а я видел антон к него при торопливо торопливо вопрос сова сова антон я видел антон и никогда не мог стоял из сумрака сумрака антон
# ==================================================
# Iteration #: 26
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 15s 2ms/step - loss: 5.1508 - acc: 0.1864 - val_loss: 8.3190 - val_acc: 0.0245
# Generating from seed: ['стать', 'внешности', 'на', 'человеческий', 'взгляд', 'ему', 'было', 'лет', 'сорок', 'а']
# стать внешности на человеческий взгляд ему было лет сорок а
# он был ее совершенно цель цель мой без юноша я видел антон к него при миг сумрака и впрямь не вмешивать а ты перед перед перед головой или ты сова сказал сказал я почувствовал антон с которым антон да за миг антон как рядом сказал я был к оперативной двери и все было была более более перед перед перед вопрос сказал ты ты же как ты перед перед головой или сова сова сова сказал я был антон и никогда не видел как не хотел мимо перед перед перед перед перед вопрос как ты сова сказал сказал я был к головой
# ==================================================
# Iteration #: 27
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 14s 2ms/step - loss: 5.0630 - acc: 0.2027 - val_loss: 8.2856 - val_acc: 0.0260
# Generating from seed: ['локоть', 'ведьмака', 'и', 'они', 'стали', 'отступать', 'миг', 'другой', 'выйдя', 'из']
# локоть ведьмака и они стали отступать миг другой выйдя из
# сумрака как девушкой по меня поделать сказал я был антон из сумрака сумрака или и никогда не видел как ты никогда не мог бы к миг при мной сказал ты вот сказал я почувствовал как цель него сказал шеф ты ее сказал как юноша он перед лет оперативной антон ты перед головой мимо мимо мимо перед более или ты сова начал я видел антон и только перед оперативной видел антон к которым рядом да и впрямь идти и легко быть как а ни сказал я видел к них антон с миг антон и заходи сказал я с шефа антон с
# ==================================================
# Iteration #: 28
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 14s 2ms/step - loss: 4.9851 - acc: 0.2128 - val_loss: 8.3018 - val_acc: 0.0280
# Generating from seed: ['для', 'высшего', 'вампира', 'которым', 'он', 'не', 'является', 'и', 'даст', 'свет']
# для высшего вампира которым он не является и даст свет
# она ее мальчик не просто жить хорошо да за миг антон к оперативной во себя к него при миг антон и почему сказал сказал я почувствовал что цель сумрака как ты сейчас к утру антон к сумрак и парень тут они оперативной или перед перед перед миг как ты так и впрямь жить сказал я у него была мы сова жить как я видел антон к миг при сумрака совершенно себя и убил ведьмак которым сказал я был мимо оперативной или ты перед головой или ты сейчас сказал шеф ты ее как с которым или ты уже они перед перед
# ==================================================
# Iteration #: 29
# Train on 7992 samples, validate on 1998 samples
# Epoch 1/1
# 7992/7992 [==============================] - 14s 2ms/step - loss: 4.9040 - acc: 0.2285 - val_loss: 8.3276 - val_acc: 0.0275
# Generating from seed: ['десны', 'зудели', 'горло', 'ссохлось', 'у', 'крови', 'вкус', 'но', 'эту', 'жажду']
# десны зудели горло ссохлось у крови вкус но эту жажду
# и жить так а а когда лишь или перед перед перед теперь да ты вот у меня антон с высокий девушкой ты сейчас антон сказал ты было сказал я видел антон я был антон из двери ты ты сумрака не видел сказал шеф вот антон я видел антон с которым ты парень не хотел перед перед мимо меня сказал я был и все быть антон я видел антон с которым антон я к оперативной антон сова тебе чем не видел антон с которым да ты ты же сказал я заметил и все ее антон с которым да за был антон

# %% [markdown]
# Возможно, бОльшее кол-во итераций могло бы улучшить предсказательную способность модели, но компьютер потянул максимум 30 итераций, на большем кол-ве он зависал посередине.
# Как видно, увеличение SEQLEN не сильно повлияло на результат, однако уменьшение размера батча несколько улучшило сгенерированный текст
